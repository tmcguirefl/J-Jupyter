# %% [markdown]
# # J Software
# ## MACD indicator

# %%
load '/users/tmcguire/j64-803-user/temp/stockmacd.ijs'

# %%
] 3{. spyraw =: gethistorical 'SPY';01;29;1993;02;20;2016
# Out:
# ┌──────────┬──────────┬──────────┬──────────┬──────────┬─────────┬──────────┐
# │Date      │Open      │High      │Low       │Close     │Volume   │Adj Close │
# ├──────────┼──────────┼──────────┼──────────┼──────────┼─────────┼──────────┤
# │2016-02-19│191.169998│192.179993│190.449997│192.00    │111764300│192.00    │
# ├──────────┼──────────┼──────────┼──────────┼──────────┼─────────┼──────────┤
# │2016-02-18│193.199997│193.270004│191.720001│192.089996│98872300 │192.089996│
# └──────────┴──────────┴──────────┴──────────┴──────────┴─────────┴──────────┘

# %%
1 tstplot spyraw
# Out:
# |domain error: cairo_image_surface_create
# |   plotcs=:    cairo_image_surface_create<"0 CAIRO_FORMAT_ARGB32,y

# %% [markdown]
# # To Do
# I need a routine that will return the image of a plot so that I can use viewrgb to display it inline. I should be able to make modifications to tstplot

# %%
load 'viewmat'
image =: readbmp <'/Users/tmcguire/myplot.bmp'
viewrgb image

# %%
 require 'trig'
   viewmat (*:@sind +/ *:@cosd) i.360
